# %% [markdown]
# <a href="https://colab.research.google.com/github/RudraYBedekar/AVTrajectoryAnalysis/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# Path to dataset
dataset_path = '/content/drive/My Drive/waymo_data/scenario/*.tfrecord'
# Out:
# Mounted at /content/drive

# %%
# !pip install waymo-open-dataset-tf-2-15-0
# !pip install pandas matplotlib scikit-learn
# Out:
# ERROR: Could not find a version that satisfies the requirement waymo-open-dataset-tf-2-15-0 (from versions: none)
# ERROR: No matching distribution found for waymo-open-dataset-tf-2-15-0
# ...

# %%
# !pip install tensorflow==2.15
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.3/475.3 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 72.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 56.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 90.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 23.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 103.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.0/442.0 kB 33.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 6.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.17.2
#     Uninstalling wrapt-1.17.2:
#       Successfully uninstalled wrapt-1.17.2
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.4
# ...

# %%
pip install tensorflow pandas matplotlib scikit-learn protobuf

# %%
# ===============================
# ✅ 1. Import Libraries
# ===============================
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# ===============================
# ✅ 2. Simulate Trajectories
# ===============================
np.random.seed(42)
num_vehicles = 3000
points_per_vehicle = 50

all_trajectories = []

for v_id in range(num_vehicles):
    x = np.cumsum(np.random.randn(points_per_vehicle))
    y = np.cumsum(np.random.randn(points_per_vehicle))
    speed = np.abs(np.random.randn(points_per_vehicle) * 5 + 30)
    acceleration = np.abs(np.random.randn(points_per_vehicle) * 0.5)
    turning_radius = np.abs(np.random.randn(points_per_vehicle) * 10 + 50)

    vehicle_df = pd.DataFrame({
        'vehicle_id': v_id,
        'x': x,
        'y': y,
        'speed': speed,
        'acceleration': acceleration,
        'turning_radius': turning_radius
    })

    all_trajectories.append(vehicle_df)

df = pd.concat(all_trajectories).reset_index(drop=True)
print(f"✅ Simulated {num_vehicles} vehicle trajectories with {len(df)} total points.")

# ===============================
# ✅ 3. Apply KMeans Clustering
# ===============================
features = df[['speed', 'acceleration', 'turning_radius']]
kmeans = KMeans(n_clusters=4, random_state=42)
df['behavior_cluster'] = kmeans.fit_predict(features)

print(f"✅ Clustering complete: {df['behavior_cluster'].nunique()} behavior clusters found.")

# ===============================
# ✅ 4. Sample for Better Visualization
# ===============================
sample_size = 300  # adjust as needed for speed
sampled_ids = np.random.choice(df['vehicle_id'].unique(), sample_size, replace=False)
sampled_df = df[df['vehicle_id'].isin(sampled_ids)]

# ===============================
# ✅ 5. Plot Clustered Trajectories
# ===============================
plt.figure(figsize=(10, 8))
for cluster in sorted(sampled_df['behavior_cluster'].unique()):
    subset = sampled_df[sampled_df['behavior_cluster'] == cluster]
    plt.plot(subset['x'], subset['y'], label=f'Cluster {cluster}', linewidth=1)

plt.title('AV Vehicle Trajectories Clustered by Behavior')
plt.xlabel('X position (meters)')
plt.ylabel('Y position (meters)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

print("✅ Project complete: Trajectory simulation, clustering, and visualization finished.")
# Out:
# ✅ Simulated 3000 vehicle trajectories with 150000 total points.
# ✅ Clustering complete: 4 behavior clusters found.
# ✅ Project complete: Trajectory simulation, clustering, and visualization finished.

# %%
import matplotlib.cm as cm

plt.figure(figsize=(12, 8))

# Use a color map for consistency
colors = cm.get_cmap('tab10', df['behavior_cluster'].nunique())

for cluster in sorted(sampled_df['behavior_cluster'].unique()):
    subset = sampled_df[sampled_df['behavior_cluster'] == cluster]
    plt.plot(
        subset['x'], subset['y'],
        label=f'Behavior {cluster}',
        linewidth=1.5,
        alpha=0.8,
        color=colors(cluster)
    )

# Make the plot clearer
plt.title('Autonomous Vehicle Trajectories by Behavior Cluster', fontsize=16)
plt.xlabel('X Position (meters)', fontsize=12)
plt.ylabel('Y Position (meters)', fontsize=12)
plt.legend(title='Cluster', fontsize=10)
plt.grid(True, linestyle='--', linewidth=0.5)
plt.tight_layout()

# Optional: Save as high-res image
plt.savefig("av_behavior_clusters.png", dpi=300)

plt.show()

# %%
from google.colab import auth
auth.authenticate_user()

import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

print("✅ Libraries imported and Google Cloud authenticated.")
# Out:
# ✅ Libraries imported and Google Cloud authenticated.

# %%
file_path = 'gs://waymo_open_dataset_motion_v_1_3_0/uncompressed/scenario/your_file_name.tfrecord'
dataset = tf.data.TFRecordDataset(file_path)

print(f"✅ Dataset file loaded from: {file_path}")
# Out:
# ✅ Dataset file loaded from: gs://waymo_open_dataset_motion_v_1_3_0/uncompressed/scenario/your_file_name.tfrecord

# %%
np.random.seed(42)
num_vehicles = 3000
points_per_vehicle = 50

all_trajectories = []
for _ in range(num_vehicles):
    x = np.cumsum(np.random.randn(points_per_vehicle))
    y = np.cumsum(np.random.randn(points_per_vehicle))
    speed = np.abs(np.random.randn(points_per_vehicle) * 5 + 30)
    acceleration = np.abs(np.random.randn(points_per_vehicle) * 0.5)
    turning_radius = np.abs(np.random.randn(points_per_vehicle) * 10 + 50)
    vehicle_id = np.repeat(_, points_per_vehicle)

    vehicle_data = pd.DataFrame({
        'vehicle_id': vehicle_id,
        'x': x,
        'y': y,
        'speed': speed,
        'acceleration': acceleration,
        'turning_radius': turning_radius
    })
    all_trajectories.append(vehicle_data)

df = pd.concat(all_trajectories).reset_index(drop=True)

print(f"✅ Simulated {num_vehicles} vehicle trajectories.")
# Out:
# ✅ Simulated 3000 vehicle trajectories.

# %%
df = df[(df['speed'] < 100) & (df['acceleration'] < 10)]
df = df.dropna()

print(f"✅ Cleaned dataset: {df.shape[0]} points remaining.")
# Out:
# ✅ Cleaned dataset: 150000 points remaining.

# %%
features = df[['speed', 'acceleration', 'turning_radius']]

# %%
kmeans = KMeans(n_clusters=4, random_state=42).fit(features)
df['behavior_cluster'] = kmeans.labels_

print(f"✅ Clustering complete: {df['behavior_cluster'].nunique()} behavior clusters found.")
# Out:
# ✅ Clustering complete: 4 behavior clusters found.

# %%
plt.figure(figsize=(10, 8))
for cluster in sorted(df['behavior_cluster'].unique()):
    subset = df[df['behavior_cluster'] == cluster]
    plt.scatter(subset['x'], subset['y'], label=f'Cluster {cluster}', alpha=0.6)

plt.title('AV Trajectory Analysis: Behavior Clusters')
plt.xlabel('X position (meters)')
plt.ylabel('Y position (meters)')
plt.legend()
plt.grid(True)
plt.show()

print("\n✅ Project completed: AV Trajectory Analysis + Visualization.")
# Out:
# ✅ Project completed: AV Trajectory Analysis + Visualization.

# %%
output_file = '/content/AV_Trajectory_Analysis_Results.xlsx'
df.to_excel(output_file, index=False)

print(f"✅ Results saved to Excel file: {output_file}")
# Out:
# ✅ Results saved to Excel file: /content/AV_Trajectory_Analysis_Results.xlsx

# %%
output_file = '/content/AV_Trajectory_Analysis_Results.xlsx'
df.to_excel(output_file, index=False)

# ✅ Download the file to your local machine
from google.colab import files
files.download(output_file)

# %%
import pandas as pd
import numpy as np

# Example trajectory dataset (replace this with your extracted data)
data = {
    'vehicle_id': np.repeat([1,2], 10),
    'time': list(range(10)) * 2,
    'x': np.random.randn(20).cumsum(),
    'y': np.random.randn(20).cumsum()
}
df = pd.DataFrame(data)

# Sort + detect missing time steps (fill with linear interpolation)
df = df.sort_values(by=['vehicle_id', 'time'])
df = df.groupby('vehicle_id').apply(lambda group: group.interpolate(method='linear')).reset_index(drop=True)
# Out:
# <ipython-input-12-5786f22c240f>:15: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby('vehicle_id').apply(lambda group: group.interpolate(method='linear')).reset_index(drop=True)

# %%
def compute_kinematics(group):
    group = group.sort_values(by='time')
    group['dx'] = group['x'].diff()
    group['dy'] = group['y'].diff()
    group['dt'] = group['time'].diff().replace(0, np.nan)

    group['speed'] = np.sqrt(group['dx']**2 + group['dy']**2) / group['dt']
    group['acceleration'] = group['speed'].diff() / group['dt']

    # Approximate curvature = 1 / turning radius
    group['curvature'] = np.abs(group['dy'] * group['dx'].shift(-1) - group['dx'] * group['dy'].shift(-1)) / \
                         ((group['dx']**2 + group['dy']**2)**1.5)
    group['turning_radius'] = 1 / (group['curvature'] + 1e-6)  # avoid division by zero

    return group

df = df.groupby('vehicle_id').apply(compute_kinematics)
df = df.replace([np.inf, -np.inf], np.nan).fillna(0)
# Out:
# <ipython-input-13-ff82afc37123>:17: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby('vehicle_id').apply(compute_kinematics)

# %%
from sklearn.cluster import KMeans

# Extract behavior features for clustering
features = df[['speed', 'acceleration', 'turning_radius']].fillna(0)
model = KMeans(n_clusters=4, random_state=42)
df['behavior_cluster'] = model.fit_predict(features)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
for cluster in sorted(df['behavior_cluster'].unique()):
    subset = df[df['behavior_cluster'] == cluster]
    plt.plot(subset['x'], subset['y'], label=f'Cluster {cluster}')

plt.title('AV Vehicle Trajectories by Behavior Cluster')
plt.xlabel('X position (m)')
plt.ylabel('Y position (m)')
plt.legend()
plt.grid(True)
plt.show()

# %%
df = df.reset_index(drop=True)  # 🪄 This solves the ambiguity

from sklearn.linear_model import LinearRegression

def predict_next_position(vehicle_group):
    model = LinearRegression()
    # Predict x based on time
    model.fit(vehicle_group['time'].values.reshape(-1,1), vehicle_group['x'].values)
    next_time = vehicle_group['time'].max() + 1
    next_x = model.predict([[next_time]])[0]
    # Predict y
    model.fit(vehicle_group['time'].values.reshape(-1,1), vehicle_group['y'].values)
    next_y = model.predict([[next_time]])[0]

    return pd.Series({'next_x': next_x, 'next_y': next_y})

predictions = df.groupby('vehicle_id').apply(predict_next_position)
print(predictions)
# Out:
#               next_x    next_y
# vehicle_id
# 1           5.449853  6.007858
# 2           9.593127  2.228704
# <ipython-input-17-2d8b2b83b0d6>:17: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   predictions = df.groupby('vehicle_id').apply(predict_next_position)
